# %% [markdown]
# # Data Loading

# %%
# functionality to solve ModuleNotFoundError
import sys
from pathlib import Path

ROOT = Path().resolve().parents[0]
sys.path.append(str(ROOT))

# %%
import pandas as pd 
from src.data import load_train_data

data = load_train_data()

# %% [markdown]
# # Dataset Overview

# %%
data.shape

# test dataframe contains 1460 rows, 81 columns
# Out:
# (1460, 81)

# %%
data.columns # view the attributes
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
# change pandas display so I don't get truncated output 
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth",None)

# %%
# access top 15 rows of data to take a look 
data.head(15)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %% [markdown]
# With reference from data_description.txt, some of the columns, though seems contain numerical values, but are actually categorical, they are:
# - MSSubClass - Identifies the type of dwelling involved in the sale. 20,30 identifies different type of houses, there is no numerical meaning, it shall be treated as a categorical attribute
#
# - OverallQual - Rates the overall material and finish of the house, it is an integer rating from 1 to 10, their numerical representations are not true quantitative distances, they are quality levels and ordinal categorical attributes. For modeling, I shall retain the ordinal encoding to avoid one-hot encoding
#
# - OverallCond - Rates the overall condition of the house, same as OverallQual

# %% [markdown]
# # Target Variable : SalePrice Analysis

# %%
# plot distrinbution of the target, SalePrice
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

plt.figure(figsize=(6,5))
sns.histplot(data['SalePrice'],kde=True)
plt.title('SalePrice Distribution')
plt.show()

# %% [markdown]
# SalePrice displays a strong right skew, with a long tail corresponding to highly priced properties.
#
# Right skews affect modeling, The score is calculated based on Root Mean Squared Error(RMSE), errors on higher-end prices will affect RMSE unequally than errors on the more common lower-mid part of the histogram. It will also affect model performance as many models such as linear regression assume normally distributed errors
#
# Applying a log transformation can reduce skewness

# %%
plt.figure(figsize=(6,5))
sns.histplot(np.log1p(data['SalePrice']), kde=True)
plt.title("Log-Transformed SalePrice")
plt.show()

# %% [markdown]
# Log transformation indeed reduced the skewness of the target, subsequently, log(SalePrice) shall be used as the modeling target

# %% [markdown]
# # Feature Typing

# %% [markdown]
# There are Two types of features
# 1. Numerical
# 2. Categorical
#
# and in numerical features, there are
# 1. Continuous
# 2. Discrete
#
# in categorical features, there are
# 1. Nominal
# 2. Ordinal
#
# I will split the attributes into nominal, ordinal, and numerical. Numerical category will contain both discrete and continuous attributes.
#
# For modeling, I will treat all numerical category as contiuous.
#
# SalePrice is the target variable, I will not include it into the categories

# %%
nominal_cols = ['MSZoning','MSSubClass', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
       'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
       'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
       'Exterior2nd', 'MasVnrType','Foundation', 'Heating','CentralAir', 'Electrical','Functional',
       'GarageType', 'GarageFinish','PavedDrive','MiscFeature',
       'SaleType', 'SaleCondition','Fence'
]

ordinal_cols = ['OverallQual','OverallCond','ExterQual', 'ExterCond',
                'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
                'HeatingQC','KitchenQual','FireplaceQu','GarageQual',
                'GarageCond','PoolQC'

]

numerical_cols = [
  col for col in data.columns
  if col not in nominal_cols + ordinal_cols + ["SalePrice"]
]

# check 
print(len(nominal_cols)+len(ordinal_cols)+len(numerical_cols)+ 1 ) # +1 for SalePrice
# Out:
# 81

# %% [markdown]
# It is to be noted that in Ordinal columns, some attribute include NaN, which means the house do not have this amenity, those attributes are:
# - BsmtQual
# - BsmtCond
# - BsmtExposure
# - BsmtFinType1
# - BsmtFinType2
# - FireplaceQu
# - GarageQual
# - GarageCond
# - PoolQC
# - Fence
#
# They need handling later on
#
# Fence attribute, one column but it rates 2 different things, wood and privacy, It will be first placed into nominal categorical attributes first

# %%
# set pandas to show all rows 
pd.set_option("display.max_rows",None)

# %%
# check constant / near- constant features 
data.nunique().sort_values()
# Out:
# Alley               2
# Street              2
# Utilities           2
# CentralAir          2
# MasVnrType          3
# HalfBath            3
# GarageFinish        3
# LandSlope           3
# BsmtHalfBath        3
# PavedDrive          3
# PoolQC              3
# ExterQual           4
# BsmtQual            4
# LotShape            4
# BsmtExposure        4
# FullBath            4
# KitchenQual         4
# BsmtFullBath        4
# Fireplaces          4
# KitchenAbvGr        4
# MiscFeature         4
# Fence               4
# BsmtCond            4
# LandContour         4
# BldgType            5
# FireplaceQu         5
# LotConfig           5
# ExterCond           5
# Electrical          5
# GarageCars          5
# GarageQual          5
# HeatingQC           5
# MSZoning            5
# YrSold              5
# GarageCond          5
# BsmtFinType2        6
# Heating             6
# BsmtFinType1        6
# RoofStyle           6
# Foundation          6
# GarageType          6
# ...

# %% [markdown]
# Binary columns: Alley , Street, Utilities, CentralAir
#
#
# The Id column is a unique identifier for each row, it is assigned value and it has no logical relationship with the Sales price, this column is to be removed from training later on

# %% [markdown]
# # Missing Values Analysis

# %% [markdown]
# From the previous .info() code, there are some features that has missing values, take a closer look at those columns

# %%
# Train data contains missing values
# Take a look at the missing values
data.isna().sum()[data.isna().sum() > 0].sort_values(ascending=False)

# This code aims to address: 
# for each column with missing values, what columns are they ? 
# how many missing value ?
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %%
# in terms of proportions
missing_prct = data.isna().mean().sort_values(ascending=False)
print(missing_prct)
# Out:
# PoolQC           0.995205
# MiscFeature      0.963014
# Alley            0.937671
# Fence            0.807534
# MasVnrType       0.597260
# FireplaceQu      0.472603
# LotFrontage      0.177397
# GarageQual       0.055479
# GarageFinish     0.055479
# GarageType       0.055479
# GarageYrBlt      0.055479
# GarageCond       0.055479
# BsmtFinType2     0.026027
# BsmtExposure     0.026027
# BsmtCond         0.025342
# BsmtQual         0.025342
# BsmtFinType1     0.025342
# MasVnrArea       0.005479
# Electrical       0.000685
# Condition2       0.000000
# BldgType         0.000000
# Neighborhood     0.000000
# LandSlope        0.000000
# LotConfig        0.000000
# Condition1       0.000000
# LandContour      0.000000
# LotShape         0.000000
# Street           0.000000
# LotArea          0.000000
# MSSubClass       0.000000
# MSZoning         0.000000
# Id               0.000000
# Utilities        0.000000
# HouseStyle       0.000000
# Foundation       0.000000
# ...

# %% [markdown]
# Top columns with missing values:
#
# - PoolQC           0.995205
# - MiscFeature      0.963014
# - Alley            0.937671
# - Fence            0.807534
# - MasVnrType       0.597260
# - FireplaceQu      0.472603
#
# 1. PoolQC - Pool Quality, Na means no pool, from data.head(15), the top 15 rows have PoolQC NaN and PoolArea 0, means most houses have no pools, that said, likely PoolArea is redundant for a lot of rows too since they do not have a pool
#
# 2. MiscFeature - Miscellaneous feature not covered in other categories, again NaN means it has no miscellaneous features, two houses with shed appeared in the first 15 rows, will the data description still show this row contains "other" which is even more miscellaneous
#
# 3. Alley -  Type of alley access, Na means no alley access
#
# 4. Fence - Fence quality, Na means no fence
#
# 5. MasVnrType - Masonry veneer type, Masonry veneer is a non-load-bearing aesthetic exterior wall, NaN corresponds to a 0 area in the first 15 rows, likely means to not have one
#
# 6. FireplaceQu- NaN means no fireplace
#
# All of these features with large proportions of missing values are features that are rare to houses selling in the market
#
# It shows us not all of those attributes have "true missing" values, for some, NaN represents the state of not having a certain feature, instead of "not having the record of it"
#
# A more meaningful analysis would be to check the missing attributes from the numerical columns, in those columns, the NaN represents missing record

# %%
for attribute in numerical_cols:
  if data[attribute].isna().any():
    print(attribute) # check if there is any missing values in numerical attributes
# Out:
# LotFrontage
# MasVnrArea
# GarageYrBlt

# %% [markdown]
# # Correlation with Target & Structured missingness

# %% [markdown]
# Next, I will inspect the correlationship of features with the target.
#
# Pearson correlation will be used, pearson correlation can be used for numerical and ordinal columns(with mapping if applicable), but it cannot be used for nominal categorical variables.
#
# It is because Pearson correlation measures linear relationships, it assumes the numbers have order and distance, so it can calculate if and how an increase in feature x would affect target y. For nominal categories, numeric labels have no logical meaning, so it cannot be used
#
# However, in this dataset, not all ordinal columns are numbers, there are ratings from 1 to 10, and there are also string categories like “Ex", "Gd", "TA", for Excellent, Good, and Average, for such columns, calculating the Pearson correlation coefficient will not work, encoding must be done before correlating
#
# I will first map catgories to ordered numbers
#
# Among the string ordinal columns, Some attributes have structured missingness, where NaN means "no such amenities", but it will be worthwhile to check if any column has actual missing data

# %%
ordinal_cols = ['OverallQual','OverallCond','ExterQual', 'ExterCond',
                'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
                'HeatingQC','KitchenQual','FireplaceQu','GarageQual',
                'GarageCond','PoolQC'
]

# check with data_description.txt to see which are the columns without structured missingness 
no_structured_missing = ['OverallQual','OverallCond','ExterQual', 'ExterCond',
                         'HeatingQC','KitchenQual']

structured_missing = [col for col in ordinal_cols if col not in no_structured_missing]
print(structured_missing)

# check for missing data 
for col in no_structured_missing:
  if data[col].isna().any():
    print(col)
# Out:
# ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'FireplaceQu', 'GarageQual', 'GarageCond', 'PoolQC']

# %% [markdown]
# There is no true missingness found in ordinal columns, I can start encoding
#
# For columns with structured missingness, for example if a house does not even have a Pool, then it is of course worse than a house with a poor pool, I will therefore treat "no such amenity" as being lower tier than "Poor amentity"

# %%
data_ord_encode = data.copy() # create a copy of data

# in the copied dataset, change structured missingness from NaN to a meaningful None
for col in structured_missing:
  data_ord_encode[col] = data_ord_encode[col].fillna("None")

# in the copied dataset, add a column of log-transformed target. 
data_ord_encode['LogSalePrice'] = np.log1p(data_ord_encode['SalePrice'])

# %% [markdown]
# Since Log-transformed SalePrice can greatly reduce the right-skew Saleprice, all subsequent analyses involving the target will be performed with LogSalePrice

# %%
data_ord_encode.head(15)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %% [markdown]
# Each string ordinal categorical attributes have different names for the tiers, for example from data_description.txt:
#
# BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement
#
# BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# In my ordinal_cols, the attributes can be classified to have 4 types of different tier systems, below I will encode them according to the system they belong

# %%
# Previously, I have already filled the NaNs of ordinal attributes with None, where applicable 
Qual_and_Con_scale = ['None','Po','Fa','TA','Gd','Ex']
Exposure_scale = ['None','No','Mn','Av','Gd']
Fintype_scale = ['None','Unf','LwQ','Rec','BLQ','ALQ','GLQ']


# define the columns that uses each scale 
qnc_cols = ['ExterQual','ExterCond','BsmtQual','BsmtCond','HeatingQC','KitchenQual','FireplaceQu',
'GarageQual','GarageCond','PoolQC']
exp_col = ['BsmtExposure']
fintype_cols = ['BsmtFinType1','BsmtFinType2']


# Generate mappings
qnc_map = {k: i for i, k in enumerate(Qual_and_Con_scale)}
exp_map = {k: i for i, k in enumerate(Exposure_scale)}
fintype_map = {k: i for i, k in enumerate(Fintype_scale)}


# apply the mappings
for col in qnc_cols:
  data_ord_encode[col] = data_ord_encode[col].map(qnc_map)

for col in exp_col:
  data_ord_encode[col] = data_ord_encode[col].map(exp_map)

for col in fintype_cols:
  data_ord_encode[col] = data_ord_encode[col].map(fintype_map)

# %% [markdown]
# Now we inspect the correlation between ordinal categorical features and the target, also that between numerical features and the target

# %%
ordinal_corr = (
  data_ord_encode[ordinal_cols + ['LogSalePrice']]
  .corr()['LogSalePrice']
  .drop('LogSalePrice')
  .sort_values(ascending=False)
)

print(ordinal_corr)
# Out:
# OverallQual     0.817185
# ExterQual       0.678840
# KitchenQual     0.667893
# BsmtQual        0.615804
# FireplaceQu     0.546362
# HeatingQC       0.473762
# GarageQual      0.363258
# BsmtExposure    0.357421
# GarageCond      0.356766
# BsmtFinType1    0.334803
# BsmtCond        0.274543
# PoolQC          0.077292
# ExterCond       0.049313
# BsmtFinType2    0.014034
# OverallCond    -0.036868
# Name: LogSalePrice, dtype: float64

# %%
data_ord_encode['ExterQual'].value_counts(dropna=False) # error check
# Out:
# ExterQual
# 3    906
# 4    488
# 5     52
# 2     14
# Name: count, dtype: int64

# %%
num_corr = (
  data_ord_encode[numerical_cols + ['LogSalePrice']]
  .corr()['LogSalePrice']
  .drop('LogSalePrice')
  .sort_values(ascending=False)
)

print(num_corr)
# Out:
# GrLivArea        0.700927
# GarageCars       0.680625
# GarageArea       0.650888
# TotalBsmtSF      0.612134
# 1stFlrSF         0.596981
# FullBath         0.594771
# YearBuilt        0.586570
# YearRemodAdd     0.565608
# GarageYrBlt      0.541073
# TotRmsAbvGrd     0.534422
# Fireplaces       0.489450
# MasVnrArea       0.430809
# BsmtFinSF1       0.372023
# LotFrontage      0.355879
# WoodDeckSF       0.334135
# OpenPorchSF      0.321053
# 2ndFlrSF         0.319300
# HalfBath         0.313982
# LotArea          0.257320
# BsmtFullBath     0.236224
# BsmtUnfSF        0.221985
# BedroomAbvGr     0.209043
# ScreenPorch      0.121208
# PoolArea         0.069798
# MoSold           0.057330
# 3SsnPorch        0.054900
# BsmtFinSF2       0.004832
# BsmtHalfBath    -0.005149
# Id              -0.017942
# MiscVal         -0.020021
# YrSold          -0.037263
# LowQualFinSF    -0.037963
# KitchenAbvGr    -0.147548
# EnclosedPorch   -0.149050
# Name: LogSalePrice, dtype: float64

# %% [markdown]
# Pearson correlation tells me how strongly is the monotonic reationship between each feature and the price
#
# Ranking from the strongest correlation to weakest (Top 3):
# 1. OverallQual from ordinal columns
# 2. GrLivArea from numerical columns
# 3. GarageCars from numerical columns
#
# Indications:
#
# Ordinal Columns
# 1. The overall material and finish of the house affects the sale price to the greatest extent
# 2. Quality features are consistantly stronger than condition features - The quality affects sale price more than conditions
# 3. Exterior, Kitchen, Basement, are the top three features that really matter,  matter more than Pool and Garage
#
#
# Numerical Columns
# 1. Size of house, size of garage, and the size of basment demonstrate strong influence over sale price
# 2. For garage, GarageCars has greater performance than GarageArea, buyers care more about car capacity

# %% [markdown]
# # Redundancy check of features

# %%
# Look for redundancy in numerical cols

# features with high correlation with each other signal they encode the same underlying idea
corr = data[numerical_cols].corr()

# %%
# heat map 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

plt.figure(figsize=(12,10))
sns.heatmap(corr, cmap="coolwarm", center=0)
plt.title("heatmap for numerical columns")
plt.show()

# %%
#for clarity, I will compute the correlation matrix again 
corr = data[numerical_cols].corr()

corr_abs = corr.abs()

# to avoid duplicated correlation pairs, only the upper triangle of the correlation matrix is considered
upper = corr_abs.where(
  np.triu(np.ones(corr_abs.shape),k=1).astype(bool)
)

high_corr_pairs = (
  upper.stack()
        .reset_index()
        .rename(columns={
          'level_0':'feature_1',
          'level_1':'feature_2',
          0:'correlation'
        })
)

high_corr_pairs  = high_corr_pairs[
  high_corr_pairs['correlation'] > 0.6
].sort_values(by='correlation', ascending=False)

print(high_corr_pairs)
# Out:
#         feature_1     feature_2  correlation
# 506    GarageCars    GarageArea     0.882475
# 114     YearBuilt   GarageYrBlt     0.825667
# 357     GrLivArea  TotRmsAbvGrd     0.825489
# 261   TotalBsmtSF      1stFlrSF     0.819530
# 309      2ndFlrSF     GrLivArea     0.687501
# 442  BedroomAbvGr  TotRmsAbvGrd     0.676620
# 190    BsmtFinSF1  BsmtFullBath     0.649212
# 143  YearRemodAdd   GarageYrBlt     0.642277
# 353     GrLivArea      FullBath     0.630012
# 316      2ndFlrSF  TotRmsAbvGrd     0.616423
# 313      2ndFlrSF      HalfBath     0.609707

# %% [markdown]
# - GarageCars and GarageArea both describe the size of the garage
# - Garage is usually built in the same period with the house
# - Larger above grade (ground) living area is related with the total rooms above ground, of course
#
# Correlated features form clusters that link to the same concept, for example, garage, size, construction period.
#
# They are retained at EDA stage, redundancy may be addressed later through regularisation

# %%
# reset pandas display 
pd.reset_option("display.max_columns")
pd.reset_option("display.max_colwidth")
pd.reset_option("display.max_rows")

# %% [markdown]
# # EDA Summary

# %% [markdown]
# - Target SalePrice is right skewed - need log transformation
# - Features can be separated into 3 categories, a large portion of missing data results from structured missingness
# - Quality matters more than conditions. Main drivers of SalePrice are the qualities of various amenities, such as area of houses, and house age (0.586 correlation with logSalePrice)
# - Correlated features identify some underlying concepts such as size and period built

# %%
# functionality to solve ModuleNotFoundError
import sys
from pathlib import Path

ROOT = Path().resolve().parents[0]
sys.path.append(str(ROOT))

# %%
import pandas as pd 
from src.data import load_train_data

data = load_train_data()

# %%
data.shape

# test dataframe contains 1460 rows, 81 columns
# Out:
# (1460, 81)

# %%
data.columns # view the attributes
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# change pandas display so I don't get truncated output 
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth",None)

# %%
# access top 15 rows of data to take a look 
data.head(15)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %% [markdown]
# There are a lot of different attributes, I will categorise into numerical & categorical, since they will be handled differently (eg different Scaling methods)

# %%
num_cols = data.select_dtypes(include="number").columns
cat_cols = data.select_dtypes(exclude="number").columns
print(f'numerical: {num_cols} \n number of attribute: {len(num_cols)}')
print()
print(f'categorical: {cat_cols}\n number of attribute: {len(cat_cols)}')
# Out:
# numerical: Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')
#  number of attribute: 38
#
# categorical: Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
# ...

# %%
# set pandas to show all rows 
pd.set_option("display.max_rows",None)

# %%
# check constant / near- constant features 
data.nunique().sort_values()
# Out:
# Alley               2
# Street              2
# Utilities           2
# CentralAir          2
# MasVnrType          3
# HalfBath            3
# GarageFinish        3
# LandSlope           3
# BsmtHalfBath        3
# PavedDrive          3
# PoolQC              3
# ExterQual           4
# BsmtQual            4
# LotShape            4
# BsmtExposure        4
# FullBath            4
# KitchenQual         4
# BsmtFullBath        4
# Fireplaces          4
# KitchenAbvGr        4
# MiscFeature         4
# Fence               4
# BsmtCond            4
# LandContour         4
# BldgType            5
# FireplaceQu         5
# LotConfig           5
# ExterCond           5
# Electrical          5
# GarageCars          5
# GarageQual          5
# HeatingQC           5
# MSZoning            5
# YrSold              5
# GarageCond          5
# BsmtFinType2        6
# Heating             6
# BsmtFinType1        6
# RoofStyle           6
# Foundation          6
# GarageType          6
# ...

# %% [markdown]
# The Id column is a unique identifier for each row, it is assigned value and it has no logical relationship with the Sales price, this column is to be removed from training later on

# %% [markdown]
# From the previous .info() code, there are some features that has missing values, take a closer look at those columns

# %%
# Train data contains missing values
# Take a look at the missing values
data.isna().sum()[data.isna().sum() > 0].sort_values(ascending=False)

# This code aims to address: 
# for each column with missing values, what columns are they ? 
# how many missing value ?
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %%
# in terms of proportions
missing_prct = data.isna().mean().sort_values(ascending=False)
print(missing_prct)
# Out:
# PoolQC           0.995205
# MiscFeature      0.963014
# Alley            0.937671
# Fence            0.807534
# MasVnrType       0.597260
# FireplaceQu      0.472603
# LotFrontage      0.177397
# GarageQual       0.055479
# GarageFinish     0.055479
# GarageType       0.055479
# GarageYrBlt      0.055479
# GarageCond       0.055479
# BsmtFinType2     0.026027
# BsmtExposure     0.026027
# BsmtCond         0.025342
# BsmtQual         0.025342
# BsmtFinType1     0.025342
# MasVnrArea       0.005479
# Electrical       0.000685
# Condition2       0.000000
# BldgType         0.000000
# Neighborhood     0.000000
# LandSlope        0.000000
# LotConfig        0.000000
# Condition1       0.000000
# LandContour      0.000000
# LotShape         0.000000
# Street           0.000000
# LotArea          0.000000
# MSSubClass       0.000000
# MSZoning         0.000000
# Id               0.000000
# Utilities        0.000000
# HouseStyle       0.000000
# Foundation       0.000000
# ...

# %% [markdown]
# Top columns with missing values:
#
# - PoolQC           0.995205
# - MiscFeature      0.963014
# - Alley            0.937671
# - Fence            0.807534
# - MasVnrType       0.597260
# - FireplaceQu      0.472603
#
# 1. PoolQC - Pool Quality, Na means no pool, from data.head(15), the top 15 rows have PoolQC NaN and PoolArea 0, means most houses have no pools, that said, likely PoolArea is redundant for a lot of rows too since they do not have a pool
#
# 2. MiscFeature - Miscellaneous feature not covered in other categories, again NaN means it has no miscellaneous features, two houses with shed appeared in the first 15 rows, will the data description still show this row contains "other" which is even more miscellaneous
#
# 3. Alley -  Type of alley access, Na means no alley access
#
# 4. Fence - Fence quality, Na means no fence
#
# 5. MasVnrType - Masonry veneer type, Masonry veneer is a non-load-bearing aesthetic exterior wall, NaN corresponds to a 0 area in the first 15 rows, likely means to not have one
#
# 6. FireplaceQu- NaN means no fireplace
#
# All of these features with large proportions of missing values are features that are rare to houses selling in the market, considering to drop them

# %%
# Look for redundancy
# numerical
corr = data[num_cols].corr()

# %%
# heat map 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

plt.figure(figsize=(12,10))
sns.heatmap(corr, cmap="coolwarm", center=0)
plt.title("heatmap for numerical columns")
plt.show()

# %%
corr_abs = corr.abs()
upper = corr_abs.where(
  np.triu(np.ones(corr_abs.shape),k=1).astype(bool)
)

high_corr_pairs = [
  col for col in upper.columns if any(upper[col]>0.8)
]

print(high_corr_pairs)
# Out:
# ['1stFlrSF', 'TotRmsAbvGrd', 'GarageYrBlt', 'GarageArea']

# %%
# reset pandas display 
pd.reset_option("display.max_columns")
pd.reset_option("display.max_colwidth")
pd.reset_option("display.max_rows")
